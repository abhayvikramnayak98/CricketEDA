# %% [markdown]
# ### <center>1. Importing the dataset</center>

# %%
# Importing modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importing the dataset
matches_df = pd.read_csv('matches.csv')
matches_df.head(10)
# Out:
#   Scorecard       Team 1       Team 2       Winner     Margin        Ground  \
# 0   ODI # 1    Australia      England    Australia  5 wickets     Melbourne
# 1   ODI # 2      England    Australia      England  6 wickets    Manchester
# 2   ODI # 3      England    Australia    Australia  5 wickets        Lord's
# 3   ODI # 4      England    Australia      England  2 wickets    Birmingham
# 4   ODI # 5  New Zealand     Pakistan  New Zealand    22 runs  Christchurch
# 5   ODI # 6      England  New Zealand      England  7 wickets       Swansea
# 6   ODI # 7      England  New Zealand    no result        NaN    Manchester
# 7   ODI # 8      England  West Indies      England   1 wicket         Leeds
# 8   ODI # 9      England  West Indies  West Indies  8 wickets      The Oval
# 9  ODI # 10  New Zealand    Australia    Australia  7 wickets       Dunedin
#
#      Match Date
# 0   Jan 5, 1971
# 1  Aug 24, 1972
# 2  Aug 26, 1972
# 3  Aug 28, 1972
# 4  Feb 11, 1973
# 5  Jul 18, 1973
# 6  Jul 20, 1973
# 7   Sep 5, 1973
# 8   Sep 7, 1973
# 9  Mar 30, 1974

# %% [markdown]
# ### <center>2. About the dataset</center>

# %%
# Information about the dataset
matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3932 entries, 0 to 3931
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Scorecard   3932 non-null   object
#  1   Team 1      3932 non-null   object
#  2   Team 2      3932 non-null   object
#  3   Winner      3932 non-null   object
#  4   Margin      3753 non-null   object
#  5   Ground      3932 non-null   object
#  6   Match Date  3932 non-null   object
# dtypes: object(7)
# memory usage: 215.2+ KB

# %%
# Description of the dataset
matches_df.describe()
# Out:
#        Scorecard     Team 1     Team 2     Winner     Margin   Ground  \
# count       3932       3932       3932       3932       3753     3932
# unique      3932         24         25         25        227      173
# top      ODI # 1  Australia  Sri Lanka  Australia  6 wickets  Sharjah
# freq           1        583        508        555        347      228
#
#          Match Date
# count          3932
# unique         3386
# top     Feb 4, 2007
# freq              6

# %% [markdown]
# ### <center>3. Pre-processing</center>

# %%
# 1. Converting the column names to lowercase and replacing spaces with underscore if found.
matches_df.columns = [col.lower().replace(' ', '_') for col in matches_df.columns]
matches_df.head(10)
# Out:
#   scorecard       team_1       team_2       winner     margin        ground  \
# 0   ODI # 1    Australia      England    Australia  5 wickets     Melbourne
# 1   ODI # 2      England    Australia      England  6 wickets    Manchester
# 2   ODI # 3      England    Australia    Australia  5 wickets        Lord's
# 3   ODI # 4      England    Australia      England  2 wickets    Birmingham
# 4   ODI # 5  New Zealand     Pakistan  New Zealand    22 runs  Christchurch
# 5   ODI # 6      England  New Zealand      England  7 wickets       Swansea
# 6   ODI # 7      England  New Zealand    no result        NaN    Manchester
# 7   ODI # 8      England  West Indies      England   1 wicket         Leeds
# 8   ODI # 9      England  West Indies  West Indies  8 wickets      The Oval
# 9  ODI # 10  New Zealand    Australia    Australia  7 wickets       Dunedin
#
#      match_date
# 0   Jan 5, 1971
# 1  Aug 24, 1972
# 2  Aug 26, 1972
# 3  Aug 28, 1972
# 4  Feb 11, 1973
# 5  Jul 18, 1973
# 6  Jul 20, 1973
# 7   Sep 5, 1973
# 8   Sep 7, 1973
# 9  Mar 30, 1974

# %%
# 2. Separating the numbers from the text in scorecard column and formatting the numbers as per the no. of digits of the last row data of the column.
num_digits = len(''.join(filter(str.isdigit, matches_df['scorecard'].iloc[-1])))
print(num_digits)
matches_df['scorecard'] = matches_df['scorecard'].str.extract('(\d+)')
matches_df['scorecard'] =  matches_df['scorecard'].str.zfill(num_digits)
matches_df.head(10)
# Out:
# 4
#   scorecard       team_1       team_2       winner     margin        ground  \
# 0      0001    Australia      England    Australia  5 wickets     Melbourne
# 1      0002      England    Australia      England  6 wickets    Manchester
# 2      0003      England    Australia    Australia  5 wickets        Lord's
# 3      0004      England    Australia      England  2 wickets    Birmingham
# 4      0005  New Zealand     Pakistan  New Zealand    22 runs  Christchurch
# 5      0006      England  New Zealand      England  7 wickets       Swansea
# 6      0007      England  New Zealand    no result        NaN    Manchester
# 7      0008      England  West Indies      England   1 wicket         Leeds
# 8      0009      England  West Indies  West Indies  8 wickets      The Oval
# 9      0010  New Zealand    Australia    Australia  7 wickets       Dunedin
#
#      match_date
# 0   Jan 5, 1971
# 1  Aug 24, 1972
# 2  Aug 26, 1972
# 3  Aug 28, 1972
# 4  Feb 11, 1973
# 5  Jul 18, 1973
# 6  Jul 20, 1973
# 7   Sep 5, 1973
# 8   Sep 7, 1973
# 9  Mar 30, 1974

# %%
# 3. Replacing the null values in the margin column to 'no margin'.
matches_df['margin'].fillna('no margin', inplace=True)
matches_df.head(10)
# Out:
#   scorecard       team_1       team_2       winner     margin        ground  \
# 0      0001    Australia      England    Australia  5 wickets     Melbourne
# 1      0002      England    Australia      England  6 wickets    Manchester
# 2      0003      England    Australia    Australia  5 wickets        Lord's
# 3      0004      England    Australia      England  2 wickets    Birmingham
# 4      0005  New Zealand     Pakistan  New Zealand    22 runs  Christchurch
# 5      0006      England  New Zealand      England  7 wickets       Swansea
# 6      0007      England  New Zealand    no result  no margin    Manchester
# 7      0008      England  West Indies      England   1 wicket         Leeds
# 8      0009      England  West Indies  West Indies  8 wickets      The Oval
# 9      0010  New Zealand    Australia    Australia  7 wickets       Dunedin
#
#      match_date
# 0   Jan 5, 1971
# 1  Aug 24, 1972
# 2  Aug 26, 1972
# 3  Aug 28, 1972
# 4  Feb 11, 1973
# 5  Jul 18, 1973
# 6  Jul 20, 1973
# 7   Sep 5, 1973
# 8   Sep 7, 1973
# 9  Mar 30, 1974

# %%
# 4. Replacing the dates having two days with the dates having the first day and then replacing the commas with spaces.
def reformat_date(date_str):
    parts = date_str.split()
    if '-' in parts[1]:
        parts[1] = parts[1].split('-')[0]
    return ' '.join(parts)
    
matches_df['match_date'] = matches_df['match_date'].apply(reformat_date)
matches_df['match_date'].replace(',', ' ', regex = True, inplace = True)
matches_df.head(10)
# Out:
#   scorecard       team_1       team_2       winner     margin        ground  \
# 0      0001    Australia      England    Australia  5 wickets     Melbourne
# 1      0002      England    Australia      England  6 wickets    Manchester
# 2      0003      England    Australia    Australia  5 wickets        Lord's
# 3      0004      England    Australia      England  2 wickets    Birmingham
# 4      0005  New Zealand     Pakistan  New Zealand    22 runs  Christchurch
# 5      0006      England  New Zealand      England  7 wickets       Swansea
# 6      0007      England  New Zealand    no result  no margin    Manchester
# 7      0008      England  West Indies      England   1 wicket         Leeds
# 8      0009      England  West Indies  West Indies  8 wickets      The Oval
# 9      0010  New Zealand    Australia    Australia  7 wickets       Dunedin
#
#      match_date
# 0   Jan 5  1971
# 1  Aug 24  1972
# 2  Aug 26  1972
# 3  Aug 28  1972
# 4  Feb 11  1973
# 5  Jul 18  1973
# 6  Jul 20  1973
# 7   Sep 5  1973
# 8   Sep 7  1973
# 9  Mar 30  1974

# %%
# 5. Converting the match_date data to datetime format
matches_df['match_date'] = pd.to_datetime(matches_df['match_date'], format='%b %d %Y', errors='coerce')
matches_df.head(10)
# Out:
#   scorecard       team_1       team_2       winner     margin        ground  \
# 0      0001    Australia      England    Australia  5 wickets     Melbourne
# 1      0002      England    Australia      England  6 wickets    Manchester
# 2      0003      England    Australia    Australia  5 wickets        Lord's
# 3      0004      England    Australia      England  2 wickets    Birmingham
# 4      0005  New Zealand     Pakistan  New Zealand    22 runs  Christchurch
# 5      0006      England  New Zealand      England  7 wickets       Swansea
# 6      0007      England  New Zealand    no result  no margin    Manchester
# 7      0008      England  West Indies      England   1 wicket         Leeds
# 8      0009      England  West Indies  West Indies  8 wickets      The Oval
# 9      0010  New Zealand    Australia    Australia  7 wickets       Dunedin
#
#   match_date
# 0 1971-01-05
# 1 1972-08-24
# 2 1972-08-26
# 3 1972-08-28
# 4 1973-02-11
# 5 1973-07-18
# 6 1973-07-20
# 7 1973-09-05
# 8 1973-09-07
# 9 1974-03-30

# %%
# 6. Extracting the year from the match_date column
matches_df['match_year'] = matches_df['match_date'].dt.year
matches_df.head(10)
# Out:
#   scorecard       team_1       team_2       winner     margin        ground  \
# 0      0001    Australia      England    Australia  5 wickets     Melbourne
# 1      0002      England    Australia      England  6 wickets    Manchester
# 2      0003      England    Australia    Australia  5 wickets        Lord's
# 3      0004      England    Australia      England  2 wickets    Birmingham
# 4      0005  New Zealand     Pakistan  New Zealand    22 runs  Christchurch
# 5      0006      England  New Zealand      England  7 wickets       Swansea
# 6      0007      England  New Zealand    no result  no margin    Manchester
# 7      0008      England  West Indies      England   1 wicket         Leeds
# 8      0009      England  West Indies  West Indies  8 wickets      The Oval
# 9      0010  New Zealand    Australia    Australia  7 wickets       Dunedin
#
#   match_date  match_year
# 0 1971-01-05        1971
# 1 1972-08-24        1972
# 2 1972-08-26        1972
# 3 1972-08-28        1972
# 4 1973-02-11        1973
# 5 1973-07-18        1973
# 6 1973-07-20        1973
# 7 1973-09-05        1973
# 8 1973-09-07        1973
# 9 1974-03-30        1974

# %%
# Description of the match_year column
matches_df['match_year'].describe()
# Out:
# count    3932.000000
# mean     2001.514751
# std        10.159153
# min      1971.000000
# 25%      1995.000000
# 50%      2003.000000
# 75%      2010.000000
# max      2017.000000
# Name: match_year, dtype: float64

# %%
matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3932 entries, 0 to 3931
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   scorecard   3932 non-null   object
#  1   team_1      3932 non-null   object
#  2   team_2      3932 non-null   object
#  3   winner      3932 non-null   object
#  4   margin      3932 non-null   object
#  5   ground      3932 non-null   object
#  6   match_date  3932 non-null   datetime64[ns]
#  7   match_year  3932 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 245.9+ KB

# %% [markdown]
# ### <center>4. Calculation & Aggregation of Data</center>

# %%
# Extracting the data from the dataset for matches happened in or after 2000
matches_df01 = matches_df[matches_df['match_year'] >= 2000]
matches_df01.head(10)
# Out:
#      scorecard       team_1       team_2       winner     margin  \
# 1531      1532  New Zealand  West Indies  New Zealand  3 wickets
# 1532      1533  New Zealand  West Indies  New Zealand  7 wickets
# 1533      1534  New Zealand  West Indies  New Zealand  4 wickets
# 1534      1535  New Zealand  West Indies  New Zealand  8 wickets
# 1535      1536    Australia     Pakistan     Pakistan    45 runs
# 1536      1537        India     Pakistan     Pakistan  2 wickets
# 1537      1538  New Zealand  West Indies  New Zealand    20 runs
# 1538      1539    Australia        India    Australia    28 runs
# 1539      1540    Australia        India    Australia  5 wickets
# 1540      1541    Australia     Pakistan    Australia  6 wickets
#
#             ground match_date  match_year
# 1531      Auckland 2000-01-02        2000
# 1532         Taupo 2000-01-04        2000
# 1533        Napier 2000-01-06        2000
# 1534    Wellington 2000-01-08        2000
# 1535      Brisbane 2000-01-09        2000
# 1536      Brisbane 2000-01-10        2000
# 1537  Christchurch 2000-01-11        2000
# 1538     Melbourne 2000-01-12        2000
# 1539        Sydney 2000-01-14        2000
# 1540     Melbourne 2000-01-16        2000

# %%
# Count values from the new dataset
matches_df01.count()
# Out:
# scorecard     2401
# team_1        2401
# team_2        2401
# winner        2401
# margin        2401
# ground        2401
# match_date    2401
# match_year    2401
# dtype: int64

# %%
# Extracting the playing countries
matches_df01['team_1'].unique()
# Out:
# array(['New Zealand', 'Australia', 'India', 'South Africa', 'England',
#        'Pakistan', 'Zimbabwe', 'West Indies', 'Bangladesh', 'Sri Lanka',
#        'Kenya', 'Netherlands', 'Canada', 'Namibia', 'Hong Kong',
#        'Asia XI', 'Africa XI', 'Bermuda', 'Ireland', 'Scotland',
#        'Afghanistan', 'U.A.E.', 'P.N.G.'], dtype=object)

# %%
# Extracting the data of the matches played by major playing countries only.
